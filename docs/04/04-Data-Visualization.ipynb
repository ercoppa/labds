# %% [markdown]
# <center>
#
# # <b style="font-family: 'LUISS', 'Lato'">Data Visualization</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Python and R for Data Science</h2>
# <h3 style="font-family: 'LUISS', 'Lato'">Management and Data Science</h3>
# <img src="https://ercoppa.github.io/labds/dist/img/cliente-luiss.png">
# <br><br><br>
#
# </center>

# %% [markdown]
# # Package `matplotlib`

# %% [markdown]
# ## `matplotlib`: installation and import

# %%
! pip3 install matplotlib pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Anatomy of a `matplolib` figure
#
# | Example | Key elements |
# | :--------: | :------- |
# | [<img src="img/anatomy.webp" width="650"/>](img/anatomy.webp) | <ul><li>Figure</li><li>Axes</li><li>Plot type: e.g., line</li><li>Plot title</li><li>Markers</li><li>Grid</li><li>Spine</li><li>Legend</li><li>Axes, {major,minor} ticks</li><li>{x,y}label, {major,minor} tick label</li></ul> |

# %% [markdown]
# ## `matplolib`: style
#
# Plots can be theme

# %%
print(' '.join(plt.style.available))
# Out:
# Solarize_Light2 _classic_test_patch _mpl-gallery _mpl-gallery-nogrid bmh classic dark_background fast fivethirtyeight ggplot grayscale seaborn seaborn-bright seaborn-colorblind seaborn-dark seaborn-dark-palette seaborn-darkgrid seaborn-deep seaborn-muted seaborn-notebook seaborn-paper seaborn-pastel seaborn-poster seaborn-talk seaborn-ticks seaborn-white seaborn-whitegrid tableau-colorblind10

# %%
plt.style.use("classic")
x = np.linspace(0, 10, 101) # create an array of 101 points from 0 to 10
plt.figure()            # create a plot figure
plt.title('MY PLOT') # add a title
plt.plot(x, np.sin(x))  # plot the sine of x

# %% [markdown]
# # Package `seaborn`
