# %% [markdown]
# <center>
#
# # <b style="font-family: 'LUISS', 'Lato'">Data Visualization</b>
#
# <h2 style="font-family: 'LUISS', 'Lato'">Python and R for Data Science</h2>
#
# <h3 style="font-family: 'LUISS', 'Lato'">Data Science and Management</h3>
# <img src="https://ercoppa.github.io/labds/dist/img/cliente-luiss.png">
# <br><br><br>
#
# </center>

# %% [markdown]
# # Package `matplotlib`

# %% [markdown]
# ## `matplotlib`: installation and import

# %%
! pip install matplotlib pandas numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## To visualize some data... we need the data
#
# We can use `pandas` to load and process the data. For instance:

# %%
url = "nutrients.csv" # "https://ercoppa.github.io/labds/04/nutrients.csv"
df = pd.read_csv(url)
df = df.set_index('Food')
df = df.sort_values(by='Carbs', ascending=True)
df
# Out:
#              Measure  Grams  Calories  Protein     Fat  Sat.Fat  Fiber  Carbs  \
# Food
# Bacon       2 slices     16        95        4    8.00     7.00    0.0      1
# Clams          3 oz.     85        87       12    1.00     0.00    0.0      2
# Asparagus   6 spears     96        18        1    0.01     0.01    0.5      3
# Cows' milk     1 qt.    976       660       32   40.00    36.00    0.0     48
# Butter       1/2 cup    112       113      114  115.00   116.00  117.0    118
#
#                            Category
# Food
# Bacon                 Meat, Poultry
# Clams                 Fish, Seafood
# Asparagus            Vegetables A-E
# Cows' milk           Dairy products
# Butter      Fats, Oils, Shortenings

# %% [markdown]
# ## Anatomy of a `matplolib` figure
#
# | Example | Key elements |
# | :--------: | :------- |
# | [<img src="https://ercoppa.github.io/labds/04/img/anatomy.webp" width="650"/>](https://ercoppa.github.io/labds/04/img/anatomy.webp) | <ul><li>Figure</li><li>Axes</li><li>Plot type: e.g., line</li><li>Plot title</li><li>Markers</li><li>Grid</li><li>Spine</li><li>Legend</li><li>Axes, {major,minor} ticks</li><li>{x,y}label, {major,minor} tick label</li></ul> |

# %% [markdown]
# ## Figure, subplots, and Axes

# %% [markdown]
# ### Figure
#
# A figure contains zero or more subplots (also dubbed *Axes* in `matplotlib`).
#
# It can be explicitly created with:

# %%
fig = plt.figure()

# %% [markdown]
# In most cases, you may omit to explicitly create it since it will be implicitly generated when creating the subplots (see next slides).

# %% [markdown]
# More details at: [`matplotlib.figure`](https://matplotlib.org/stable/api/figure_api.html)

# %% [markdown]
# ### Figure size
#
# By default a figure is 640x480 pixels. However, we can set an arbitrary size:

# %%
fig = plt.figure(figsize=(10, 5)) # figsize is (width, height) in inches

# %% [markdown]
# Alternatevely, we can set the figure's DPI ("dots-per-inch"):

# %%
fig = plt.figure(dpi=300)

# %% [markdown]
# Setting the DPI will preserve the original ratio beetween width and height.

# %% [markdown]
# ### Subplots and Axes
#
# To create a figure with a ***single*** subplot (`Axes`):

# %%
fig, ax = plt.subplots() 
print(fig)
print(ax)
# Out:
# Figure(640x480)
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# Mere details at: [`matplotlib.pyplot.subplots`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)

# %% [markdown]
# ### Subplots and Axes (cont'd)
#
# To create a figure with with **NxM** (e.g., N=3, M=2) subplots (`Axes`):

# %%
fig, axs = plt.subplots(3, 2) # 3 rows, 2 columns
print(fig)
print(axs)
# Out:
# Figure(640x480)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %% [markdown]
# ### Subplots and Axes: setting the figure size
#
# When creating the figure from `subplots`, we can still set the figure size using the `figsize` or `dpi` arguments. E.g.:

# %%
fig, axs = plt.subplots(3, 2, dpi=120) # 3 rows, 2 columns
print(fig)
# Out:
# Figure(768x576)

# %% [markdown]
# ## Functional interface vs. Object-Oriented interface
#
# When using `matplotlib` we have two approaches:
#
# - **Object-Oriented interface (OO)**: given an `Axes`, we call methods over that `Axes` to modify its content. E.g., `ax.set_title("Title")`. ***This is the approach that we will adopt***.
#
# - **Functional interface**: we use functions from `pyplot`, which will modify the state of the *current* `Axes`. E.g., `plt.title("Title")`. This approach is problemetic, e.g., when we want to deal with multiple plots within the same figure since it is not clear which `Axes` we want to update. This approach was inspired by MATLAB.
#
# For more details, see: [https://matplotlib.org/matplotblog/posts/pyplot-vs-object-oriented-interface/](https://matplotlib.org/matplotblog/posts/pyplot-vs-object-oriented-interface/)

# %% [markdown]
# ## Plot types

# %% [markdown]
# <center>
#
# <img src="https://ercoppa.github.io/labds/04/img/plot-type-1.png" width="600">
#
# </center>
#
# <div align="center">
# <b><a href="https://matplotlib.org/stable/gallery/index.html">Gallery</a></b>
# </div>

# %% [markdown]
# <center>
#
# <img src="https://ercoppa.github.io/labds/04/img/plot-type-2.png" width="600">
#
# </center>
#
# <div align="center">
# <b><a href="https://matplotlib.org/stable/gallery/index.html">Gallery</a></b>
# </div>

# %% [markdown]
# <center>
#
# <img src="https://ercoppa.github.io/labds/04/img/plot-type-3.png" width="600">
#
# </center>
#
# <div align="center">
# <b><a href="https://matplotlib.org/stable/gallery/index.html">Gallery</a></b>
# </div>

# %% [markdown]
# ### Creating a specific plot type
#
# Given an `Axes`, we can populate it with one or more plots using the methods of `Axes`:
#
# |     |  | ||
# | -------- | ------- | ------- | ------- |
# | <img src="https://ercoppa.github.io/labds/04/img/axes-functions-1.png" width="150">  | <img src="https://ercoppa.github.io/labds/04/img/axes-functions-3.png"  width="150">    | <img src="https://ercoppa.github.io/labds/04/img/axes-functions-2.png"  width="150"> | <img src="https://ercoppa.github.io/labds/04/img/axes-functions-4.png"  width="150">     |

# %% [markdown]
# ### Line plot

# %%
fig, ax = plt.subplots()
points = ax.plot(range(df.index.size), df['Carbs'].values)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.plot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html)

# %% [markdown]
# ### Scatter plot

# %%
fig, ax = plt.subplots()
points = ax.scatter(df.index, df.Carbs)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.scatter`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html)

# %% [markdown]
# ### Horizontal bar plot

# %%
fig, ax = plt.subplots()
bars = ax.barh(df.index, df.Carbs)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.barh`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.barh.html)

# %% [markdown]
# ### Vertical bar plot

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df.Carbs)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.bar`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.bar.html)

# %% [markdown]
# ### Stacked bar plot

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df["Protein"])
bars = ax.bar(df.index, df["Fat"], bottom=df["Protein"])

# %% [markdown]
# ### Pie chart

# %%
fig, ax = plt.subplots()
slices = ax.pie(df.Carbs, labels=df.index)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.pie`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.pie.html)

# %% [markdown]
# ### Box plot

# %%
fig, ax = plt.subplots()
slices = ax.boxplot(df.Carbs, tick_labels=["Carbs"]) # vert=False to make it horizontal

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.boxplot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.boxplot.html)

# %% [markdown]
# ### Violin plot
#
# A popular alternative to a boxplot is:

# %%
fig, ax = plt.subplots()
slices = ax.violinplot(df.Carbs) # vert=False to make it horizontal

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.violinplot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.violinplot.html)

# %% [markdown]
# ### Histogram

# %%
fig, ax = plt.subplots()
data = np.random.standard_normal(100) # 100 random numbers
slices = ax.hist(data, bins=10)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.hist`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html)

# %% [markdown]
# ### Fill between

# %%
x = [1, 3, 5, 7, 9]
y1 = [1, 3, 5, 7, 9]
y2 = [2, 5, 8, 9, 12]

fig, ax = plt.subplots()
lines = ax.fill_between(x, y1, y2)

# %% [markdown]
# Mere details at: [`matplotlib.axes.Axes.fill_between`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.fill_between.html)

# %% [markdown]
# ### Combining different plot types into an Axes
#
# We can add more than one plot within the same `Axes`:

# %%
fig, ax = plt.subplots()
line = ax.plot(range(df.index.size), df['Carbs'].values)
points = ax.plot(range(df.index.size), df['Protein'].values)

# %% [markdown]
# ### Combining different plots types into the same figure
#
# We can also  add the plots in distincts axes:

# %%
fig, axes = plt.subplots(1, 2)
line = axes[0].plot(range(df.index.size), df['Carbs'].values)
points = axes[0].plot(range(df.index.size), df['Protein'].values)
slices = axes[1].boxplot([df.Carbs, df.Protein], tick_labels=["Carbs", "Protein"])

# %% [markdown]
# ## Plot styling

# %% [markdown]
# ### Pick a style
#
# `matplotlib` ships with many styles that can drastically change the look of a plot, e.g., dark theme.
# Pick your favorite style from: [styles](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
#
# For instance, given the style `fivethirtyeight`, apply to your plots with:

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()
slices = ax.pie(df.Carbs, labels=df.index)

# %% [markdown]
# which is quite different from the `default` style:

# %%
plt.style.use('default')
fig, ax = plt.subplots()
slices = ax.pie(df.Carbs, labels=df.index)

# %% [markdown]
# See: [`matplotlib.style.use`](https://matplotlib.org/stable/api/style_api.html#matplotlib.style.use)

# %% [markdown]
# ### Setting a title to the figure

# %%
fig, axes = plt.subplots(1, 2)
fig.suptitle("Nutrients", fontsize=16, fontweight='bold', y=0.80)
slices = axes[0].pie(df.Carbs, labels=df.index)
slices = axes[1].pie(df.Protein, labels=df.index)

# %% [markdown]
# See: [`matplotlib.figure.Figure.suptitle`](https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.suptitle.html#matplotlib-figure-figure-suptitle)

# %% [markdown]
# ### Setting a title to an Axes

# %%
fig, axes = plt.subplots(1, 2)
slices = axes[0].pie(df.Carbs, labels=df.index)
axes[0].set_title("Carbs", fontsize=16, fontweight='bold')
slices = axes[1].pie(df.Protein, labels=df.index)
axes[1].set_title("Protein", fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Protein')

# %% [markdown]
# See: [`matplotlib.axes.Axes.set_title`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_title.html)

# %% [markdown]
# ### Setting x or y labels

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Carbohydrates', fontsize = 8)
ax.set_ylabel('Food', fontsize = 8)
# Out:
# Text(0, 0.5, 'Food')

# %% [markdown]
# See: [`matplotlib.axes.Axes.set_xlabel`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xlabel.html) and [`matplotlib.axes.Axes.set_ylabel`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_ylabel.html)

# %% [markdown]
# ### Adding grid lines

# %%
fig, ax = plt.subplots()
ax.grid(axis='y', linestyle='-', alpha=0.8)
ax.grid(axis='x', linestyle='--', alpha=0.6)

# %% [markdown]
# See: [`matplotlib.axes.Axes.grid`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.grid.html#)

# %% [markdown]
# ### Rotate x or y ticks labels

# %%
fig, ax = plt.subplots()
ax.tick_params(axis='x', labelrotation=45)
ax.tick_params(axis='y', labelrotation=45)

# %% [markdown]
# See: [`matplotlib.axes.Axes.tick_params`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.tick_params.html)

# %% [markdown]
# ### Change color, size, and symbol of the markers in a scatter plot

# %%
fig, ax = plt.subplots()
points = ax.scatter(df.index, df.Carbs, 
                color='green', 
                marker='s',     #  
                s=df.Carbs*2)   # make the size proportional to the value

# %% [markdown]
# See: [`matplotlib.markers`](https://matplotlib.org/stable/api/markers_api.html)

# %% [markdown]
# ### Change color, size, marker, and style of a line in a plot

# %%
fig, ax = plt.subplots()
points = ax.plot(range(df.index.size), df['Carbs'].values,
                color='red',
                linestyle='--', 
                marker='s',
                markersize=10)

# %% [markdown]
# See: [`matplotlib.lines.Line2D`](https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) and [Linestyles](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)

# %% [markdown]
# ### Adding label on top of each bar

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df.Carbs) # vertical bar plot
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 0.1, round(yval, 2), ha='center', va='bottom')

# %% [markdown]
# ### Add percentage label in a pie chart

# %%
fig, ax = plt.subplots()
slices = ax.pie(df.Carbs, labels=df.index, autopct='%1.1f%%')

# %% [markdown]
# ### Add a legend

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df["Protein"])
bars = ax.bar(df.index, df["Fat"], bottom=df["Protein"])
legend = ax.legend(df[["Fat", "Sat.Fat"]].columns)

# %% [markdown]
# ### Change x and y limits

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df.Carbs) # vertical bar plot
for bar in bars:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1, round(bar.get_height(), 2), ha='center', va='bottom')
ax.set_xlim(-1, 5)
_ = ax.set_ylim(0, 140)

# %% [markdown]
# ## Plot exporting (PNG, PDF)

# %% [markdown]
# ## How to visualize a plot
#
# While when working in a notebook any plot is automatically shown, **when writing a Python script**, we have to explitly decide when to show or export a figure.
#
# If we want to visualize the plot in a seperate window:

# %%
plt.show()

# %% [markdown]
# ## How to save a plot

# %%
fig, ax = plt.subplots()
bars = ax.bar(df.index, df["Protein"])
plt.savefig("file.png") # save in PNG
plt.savefig("file.pdf") # save in PDF
plt.close() # close the figure to avoid displaying it

# %% [markdown]
# ## Documentation
#
# * **User guide**: [https://matplotlib.org/stable/users/index.html](https://matplotlib.org/stable/users/index.html)
# * **API**: [https://matplotlib.org/stable/api/index.html](https://matplotlib.org/stable/api/index.html)

# %% [markdown]
# # Package `seaborn`

# %% [markdown]
# ## Why `seaborn`?
#
# `matplotlib` is *extremely* powerful. However, it can be very tricky when aiming at some *advanced* plots. For instance, given a dataset, if we want to plot:
# - a line that represents the average of the data points over a specific x
# - the confidence interval for each data points over a specific x
#
# <center>
# <img src="https://ercoppa.github.io/labds/04/img/seaborn-lineplot.png" width="250">
# </center>
#
# In `matplotlib`, we have to:
# - compute the average
# - `plot` the line for the average
# - compute the confindence interval
# - plot the confidence intervals with, e.g., `fill_between`

# %% [markdown]
# ## `seaborn`: `matplotlib` for the humans
#
# `seaborn` is a data visualization library based on ``matplotlib``. It provides a high-level interface for drawing *attractive* and **informative statistical** graphics.
#
# <center>
# <img src="https://ercoppa.github.io/labds/04/img/seaborn-plots.png" >
# </center>
#
# It comes with convenient *shortcuts* to build several nice plots using `matplotlib`. Moreover, it naturally fits with `pandas` and `scikit-learn`.

# %% [markdown]
# ## `seaborn`: installation
#
# Install it with `pip3`:

# %%
! pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## `seaborn`: installation
#
# Import it:

# %%
import seaborn as sns

# %% [markdown]
# ## Some data to plot
#
# In our examples, we reuse a few dummy datasets from `searbon`:

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## `seaborn` theme
#
# We can use the `matplotlib` style from `seaborn`:

# %%
# Apply the default theme
sns.set_theme()

# %% [markdown]
# ## A nicer scatter plot

# %%
ax = sns.scatterplot(data=tips, x="total_bill", y="tip", hue="size")

# %% [markdown]
# See: [`seaborn.scatterplot`](https://seaborn.pydata.org/generated/seaborn.scatterplot.html#)

# %% [markdown]
# ## A nicer scatter plot with linear regression

# %%
l = sns.lmplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %% [markdown]
# See: [`seaborn.lmplot`](https://seaborn.pydata.org/generated/seaborn.lmplot.html)

# %% [markdown]
# ## A nicer line plot with confidence intervals

# %%
lines = sns.lineplot(data=tips, x="size", y="tip", errorbar="ci")

# %% [markdown]
# See: [`seaborn.lineplot`](https://seaborn.pydata.org/generated/seaborn.lineplot.html)

# %% [markdown]
# ## A nicer histogram

# %%
s = sns.displot(data=tips, x="total_bill", kde=True)

# %% [markdown]
# See: [`seaborn.displot`](https://seaborn.pydata.org/generated/seaborn.displot.html)

# %% [markdown]
# ## A nice categorical plot

# %%
s = sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")

# %% [markdown]
# See: [`seaborn.catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html)

# %% [markdown]
# ## A nice categorical plot with violins

# %%
s = sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %% [markdown]
# ## A nice barplot plot with errorbars

# %%
s = sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")

# %% [markdown]
# ## Combine `matplotlib` and  `seaborn` plots

# %%
fix, axes = plt.subplots(1, 2)
axes[0].scatter(tips['size'].values, tips.tip.values)
s = sns.scatterplot(data=tips, x="day", y="total_bill", ax=axes[1])

# %% [markdown]
# ## Combine `matplotlib` and  `seaborn` plots (cont'd)
#
# Unfortunately, some `seaborn` plots cannot be mixed with `matplotlib` plots within the same figure. Indeed, such plots are dubbed *figure-level*. For instance, `catplot` is figure-level and the following code will generate two distinct figures:

# %%
fix, axes = plt.subplots(1, 2)
axes[0].scatter(tips['size'].values, tips.tip.values)
s = sns.catplot(data=tips, x="day", y="total_bill", ax=axes[1])
# Out:
# /home/ercoppa/.local/lib/python3.10/site-packages/seaborn/categorical.py:2761: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Documentation
#
# * **Tutorial**: [https://seaborn.pydata.org/tutorial.html](https://seaborn.pydata.org/tutorial.html)
# * **API**: [https://seaborn.pydata.org/api.html](https://seaborn.pydata.org/api.html)
